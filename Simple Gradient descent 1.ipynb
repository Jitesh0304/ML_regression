# %% [markdown]
# # Equation , slope

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # example of subplot

# %%
plt.figure(figsize=(13,7))
plt.subplot(2,3,1)                                        
plt.subplot(2,3,2)                                                   
plt.subplot(2,3,3)                                                   
plt.subplot(2,3,4)                                                   
plt.subplot(2,3,5)
plt.subplot(2,3,6)
plt.show()

# %% [markdown]
# ## Simple cost function

# %% [markdown]
# ##  $$f(x) = x^2 +x + 1$$

# %%
def f(x): 
    return x**2 + x + 1

# %%
x_1 = np.linspace(-4,3,200)

# %%
plt.plot (x_1 , f(x_1) , c = 'black' , linewidth= 3)    
plt.grid()
plt.show()

# %%
def df(x):                                 
    return 2*x + 1

# %%
plt.plot(x_1 , df(x_1) , linewidth = 3 , c = "red")
plt.grid()
plt.show()

# %%
plt.figure(figsize = (15,6))

plt.subplot(1,2,1)                                        
                                                           
plt.plot (x_1 , f(x_1) , c = 'black' , linewidth= 3)                           
plt.grid()

plt.subplot(1,2,2)                                                      

plt.plot(x_1 , df(x_1) , linewidth = 3 , c = "red")
plt.grid()
plt.show()

# %%
new_x = 3                                       

gamma = 0.1                   

for i in range(30):

    previous_x = new_x                     
                                                 
    slope = df(previous_x)

    new_x = previous_x - gamma * slope
    
print(round(new_x,2))
# Out:
# -0.5

# %%
new_x = 3

gamma = 0.1

x_list = [new_x]                                    

slope_list = [df(new_x)]


for i in range(100):

    previous_x = new_x

    slope = df(previous_x)

    new_x = previous_x - gamma * slope
                                                                                                      
    x_list.append(new_x)                             
    
    slope_list.append(df(new_x))        
    
print(round(new_x,2))
# Out:
# -0.5

# %%
print(x_list)
# Out:
# [3, 2.3, 1.7399999999999998, 1.2919999999999998, 0.9335999999999998, 0.6468799999999998, 0.41750399999999976, 0.2340031999999998, 0.08720255999999982, -0.03023795200000015, -0.12419036160000013, -0.1993522892800001, -0.25948183142400005, -0.30758546513920004, -0.34606837211136005, -0.376854697689088, -0.4014837581512704, -0.4211870065210163, -0.43694960521681303, -0.44955968417345044, -0.45964774733876035, -0.46771819787100827, -0.4741745582968066, -0.47933964663744527, -0.4834717173099562, -0.48677737384796493, -0.48942189907837197, -0.49153751926269756, -0.49323001541015804, -0.49458401232812643, -0.4956672098625011, -0.4965337678900009, -0.4972270143120007, -0.4977816114496006, -0.49822528915968045, -0.49858023132774437, -0.4988641850621955, -0.4990913480497564, -0.4992730784398051, -0.4994184627518441, -0.4995347702014753, -0.49962781616118024, -0.4997022529289442, -0.49976180234315537, -0.4998094418745243, -0.49984755349961946, -0.49987804279969555, -0.49990243423975644, -0.4999
# ...

# %%
print(slope_list)
# Out:
# [7, 5.6, 4.4799999999999995, 3.5839999999999996, 2.8671999999999995, 2.29376, 1.8350079999999995, 1.4680063999999997, 1.1744051199999996, 0.9395240959999998, 0.7516192767999997, 0.6012954214399998, 0.4810363371519999, 0.3848290697215999, 0.3078632557772799, 0.24629060462182395, 0.19703248369745918, 0.15762598695796737, 0.12610078956637394, 0.10088063165309913, 0.0807045053224793, 0.06456360425798346, 0.051650883406386794, 0.04132070672510946, 0.03305656538008761, 0.026445252304070133, 0.02115620184325606, 0.01692496147460487, 0.01353996917968392, 0.010831975343747136, 0.008665580274997753, 0.006932464219998158, 0.0055459713759985485, 0.004436777100798817, 0.0035494216806390977, 0.002839537344511256, 0.002271629875609027, 0.0018173039004871772, 0.001453843120389764, 0.0011630744963118111, 0.0009304595970494045, 0.0007443676776395236, 0.0005954941421115745, 0.0004763953136892596, 0.00038111625095138546, 0.00030489300076108616, 0.00024391440060889114, 0.0001951315204871129, 0.0001561052
# ...

# %%
plt.figure(figsize =(18,8))

plt.subplot(1,2,1)

plt.grid()

plt.plot(x_1, f(x_1))


plt.scatter(x_list, f(np.array(x_list)), color = 'red')
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.subplot(1,2,2)

plt.grid()
plt.plot(x_1, df(x_1))
plt.scatter(x_list, slope_list, color = 'navy')
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)


plt.show()

# %%
new_x = 3
gamma = 0.1
x_list = [new_x]
slope_list =[df(new_x)]
precision = 0.001                            

for i in range(200):
    previous_x = new_x
    slope = df(previous_x)
    new_x = previous_x - gamma * slope
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    step_size = abs(new_x - previous_x)                
    
    if step_size < precision:
        
        print('loop ran this many times:', i, '\n')
        
        break 
    
print(round(new_x,2))

print()                              

print(x_list)

print()

print(slope_list)
# Out:
# loop ran this many times: 30
#
# -0.5
#
# [3, 2.3, 1.7399999999999998, 1.2919999999999998, 0.9335999999999998, 0.6468799999999998, 0.41750399999999976, 0.2340031999999998, 0.08720255999999982, -0.03023795200000015, -0.12419036160000013, -0.1993522892800001, -0.25948183142400005, -0.30758546513920004, -0.34606837211136005, -0.376854697689088, -0.4014837581512704, -0.4211870065210163, -0.43694960521681303, -0.44955968417345044, -0.45964774733876035, -0.46771819787100827, -0.4741745582968066, -0.47933964663744527, -0.4834717173099562, -0.48677737384796493, -0.48942189907837197, -0.49153751926269756, -0.49323001541015804, -0.49458401232812643, -0.4956672098625011, -0.4965337678900009]
#
# ...

# %%
plt.figure(figsize =(18,8))

plt.subplot(1,2,1)

plt.grid()
plt.plot(x_1, f(x_1))

values = np.array(x_list)

plt.scatter(x_list, f(values), color = 'red')
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.subplot(1,2,2)

plt.grid()
plt.plot(x_1, df(x_1))
plt.scatter(x_list, slope_list, color = 'navy')
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)


plt.show()

# %% [markdown]
# # Gradient decent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.001, max_iter=200):
    
    new_x = initial_guess
    
    x_list = [new_x]
    
    slope_list = [derivative_func(new_x)]
    
    
    for i in range(max_iter):
        
        
        previous_x = new_x
        
        gradient = derivative_func(previous_x)               # slop
        
        new_x = previous_x - multiplier * gradient
        
        step_size = abs(new_x - previous_x)
        
        x_list.append(new_x)
        
        slope_list.append(derivative_func(new_x))
        
        if step_size < precision:
            
            break 
            
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func = df , initial_guess = 3, precision=0.00001)

# %%
print(round(local_min,2))
# Out:
# -0.5

# %%
len(list_x)
# Out:
# 52

# %%
print(deriv_list)
# Out:
# [7, 5.6, 4.4799999999999995, 3.5839999999999996, 2.8671999999999995, 2.29376, 1.8350079999999995, 1.4680063999999997, 1.1744051199999996, 0.9395240959999998, 0.7516192767999997, 0.6012954214399998, 0.4810363371519999, 0.3848290697215999, 0.3078632557772799, 0.24629060462182395, 0.19703248369745918, 0.15762598695796737, 0.12610078956637394, 0.10088063165309913, 0.0807045053224793, 0.06456360425798346, 0.051650883406386794, 0.04132070672510946, 0.03305656538008761, 0.026445252304070133, 0.02115620184325606, 0.01692496147460487, 0.01353996917968392, 0.010831975343747136, 0.008665580274997753, 0.006932464219998158, 0.0055459713759985485, 0.004436777100798817, 0.0035494216806390977, 0.002839537344511256, 0.002271629875609027, 0.0018173039004871772, 0.001453843120389764, 0.0011630744963118111, 0.0009304595970494045, 0.0007443676776395236, 0.0005954941421115745, 0.0004763953136892596, 0.00038111625095138546, 0.00030489300076108616, 0.00024391440060889114, 0.0001951315204871129, 0.0001561052
# ...

# %%
plt.figure(figsize =(18,8))


plt.subplot(1,2,1)

plt.grid()
plt.plot(x_1, f(x_1))

values = np.array(list_x)

plt.scatter(list_x, f(values), color = 'red')
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.subplot(1,2,2)

plt.grid()
plt.plot(x_1, df(x_1))
plt.scatter(list_x, deriv_list, color = 'navy')
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)


plt.show()

# %% [markdown]
# # $$ g(x) = x^4 - 4x^2 + 5 $$

# %%
def g(x):
    return x**4 - 4*x**2 + 5

# %%
x_2 = np.linspace(-2,2,500)

# %%
plt.plot(x_2, g(x_2), c = 'red', linewidth = 4)
plt.grid()
plt.show()

# %%
def dg(x):
    
    return 4*x**3 - 8*x

# %%
plt.plot(x_2, dg(x_2), c = 'red', linewidth = 3)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (15, 7))


plt.subplot(1,2,1)

plt.plot(x_2, g(x_2), c = 'navy', linewidth = 3)
plt.grid()



plt.subplot(1,2,2)

plt.plot(x_2, dg(x_2), c = 'red', linewidth = 3)
plt.grid()



plt.show()

# %% [markdown]
# # gradient decent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.001, max_iter=200):
    
    new_x = initial_guess
    
    x_list = [new_x]
    
    slope_list = [derivative_func(new_x)]
    
    
    for i in range(max_iter):
        
        
        previous_x = new_x
        
        gradient = derivative_func(previous_x)
        
        new_x = previous_x - multiplier * gradient
        
        step_size = abs(new_x - previous_x)
        
        x_list.append(new_x)
        
        slope_list.append(derivative_func(new_x))
        
        if step_size < precision:
            
            break 
            
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=2, multiplier=0.01, precision=0.00001)

# %%
round(local_min,3)
# Out:
# 1.414

# %%
len(list_x)
# Out:
# 51

# %%
print(list_x)
# Out:
# [2, 1.84, 1.73801984, 1.6670590646886698, 1.6151077745402522, 1.5757913272223372, 1.5453395816978257, 1.521351311052279, 1.5022121144811564, 1.4867909314756558, 1.4742693403753129, 1.4640396750886189, 1.4556412308041173, 1.4487187022692356, 1.4429941842924336, 1.4382477599201233, 1.434303703776821, 1.4310204612758353, 1.4282832304896889, 1.4259983780115937, 1.4240891730050105, 1.4224924857810461, 1.4211562036171737, 1.420037187776003, 1.4190996443106458, 1.4183138150170151, 1.4176549187334537, 1.4171022902730885, 1.4166386766940162, 1.4162496597629153, 1.4159231802955419, 1.415649145213581, 1.415419102094756, 1.4152259690316042, 1.4150638099820265, 1.4149276476562498, 1.4148133074604612, 1.4147172871957288, 1.41463664815811, 1.4145689240519026, 1.4145120447507453, 1.4144642724498897, 1.4144241481700328, 1.4143904469163193, 1.4143621400794084, 1.4143383638999585, 1.414318393012346, 1.414301618245046, 1.414287527989637, 1.4142756925625295, 1.4142657510771195]

# %%
print(deriv_list)
# Out:
# [16, 10.198016, 7.096077531133007, 5.195129014841767, 3.9316447317914953, 3.0451745524511438, 2.398827064554684, 1.9139196571122472, 1.5421183005500616, 1.2521591100342881, 1.0229665286694107, 0.8398444284501476, 0.6922528534881813, 0.5724517976802037, 0.4746424372310276, 0.394405614330239, 0.3283242500985555, 0.2737230786146352, 0.2284852478095285, 0.19092050065831145, 0.15966872239643237, 0.13362821638725642, 0.11190158411706719, 0.09375434653570913, 0.0785829293630691, 0.06588962835615142, 0.055262846036525204, 0.046361357907223066, 0.03890169311009117, 0.032647946737338174, 0.027403508196076842, 0.02300431188252361, 0.019313306315169143, 0.01621590495778058, 0.013616232577684073, 0.011434019578853594, 0.009602026473237046, 0.008063903761875935, 0.006772410620742519, 0.005687930115717776, 0.004777230085563744, 0.004012427985678357, 0.003370125371347399, 0.0028306836910960698, 0.002377617944988586, 0.0019970887612519306, 0.001677476729993188, 0.0014090255409175967, 0.00118354271075
# ...

# %%
plt.figure(figsize =(18,8))




plt.subplot(1,2,1)

plt.grid()
plt.plot(x_2, g(x_2))


values = np.array(list_x)

plt.scatter(list_x, g(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.subplot(1,2,2)

plt.grid()
plt.plot(x_2, dg(x_2))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)


plt.show()

# %% [markdown]
# # $$ h(x) = x^5 - 2x^4 + 2 $$

# %%
def h(x):
    return x**5 - 2*x**4 + 2

# %%
x_3 = np.linspace(-2.5 , 2.5 ,1000)

# %%
plt.plot(x_3, h(x_3), c = 'red', linewidth = 2)
plt.grid()
plt.show()

# %%
def dh(x):
    
    return 5*x**4 - 8*x**3

# %%
plt.plot(x_3, dh(x_3), c = 'red', linewidth = 2)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (15, 7))


plt.subplot(1,2,1)

plt.plot(x_3, h(x_3), c = 'navy', linewidth = 2)
plt.grid()



plt.subplot(1,2,2)

plt.plot(x_3, dh(x_3), c = 'red', linewidth = 2)
plt.grid()



plt.show()

# %%
plt.figure(figsize = (15, 7))


plt.subplot(1,2,1)

plt.plot(x_3, h(x_3), c = 'navy', linewidth = 2)
plt.grid()
plt.xlim(-1.2, 2.5)
plt.ylim(-1, 5)
plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)


plt.subplot(1,2,2)

plt.plot(x_3, dh(x_3), c = 'red', linewidth = 2)
plt.grid()
plt.xlim(-1, 2)
plt.ylim(-4, 5)
plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()

# %% [markdown]
# # gradient decent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.1, precision=0.001, max_iter=200):
    
    new_x = initial_guess
    
    x_list = [new_x]
    
    slope_list = [derivative_func(new_x)]
    
    
    for i in range(max_iter):
        
        
        previous_x = new_x
        
        gradient = derivative_func(previous_x)
        
        new_x = previous_x - multiplier * gradient
        
        step_size = abs(new_x - previous_x)
        
        x_list.append(new_x)
        
        slope_list.append(derivative_func(new_x))
        
        if step_size < precision:
            
            break 
            
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=1.9, multiplier=0.01, precision=0.00001)

# %%
round(local_min, 2)
# Out:
# 1.6

# %%
print(list_x)
# Out:
# [1.9, 1.797115, 1.7399122001785374, 1.7030647372520222, 1.6776097094874234, 1.6592883011059323, 1.6457456227538518, 1.6355501428133643, 1.6277733067520288, 1.6217839613081573, 1.6171378900684918, 1.6135140542297606, 1.6106756521296068, 1.6084452216096072, 1.6066881078519415, 1.6053011348423143, 1.6042046354539286, 1.6033367195369064, 1.602649075113793, 1.6021038453083905, 1.6016712759059892, 1.6013279249050463, 1.6010552881826747, 1.600838737245623, 1.600666693579702, 1.6005299839830032, 1.6004213353684724, 1.6003349776980351, 1.6002663311677934, 1.6002117593020955, 1.6001683737754184, 1.6001338799387714, 1.6001064544439814, 1.6000846482218656, 1.6000673095143985, 1.6000535227860373, 1.6000425602193797, 1.6000338431908654]

# %%
len(list_x)
# Out:
# 38

# %%
print(deriv_list)
# Out:
# [10.288499999999992, 5.720279982146266, 3.6847462926515107, 2.545502776459884, 1.8321408381491082, 1.3542678352080344, 1.0195479940487573, 0.7776836061335501, 0.5989345443871485, 0.4646071239665517, 0.3623835838731253, 0.28384021001536297, 0.22304305199995866, 0.1757113757665678, 0.13869730096272548, 0.10964993883857943, 0.08679159170222306, 0.06876444231133405, 0.05452298054024851, 0.04325694024012705, 0.03433510009428886, 0.02726367223716153, 0.021655093705170714, 0.017204366592096676, 0.013670959669894955, 0.0108648614530793, 0.008635767043720932, 0.0068646530241665005, 0.005457186569799433, 0.004338552667704221, 0.003449383664694494, 0.0027425494790094262, 0.0021806222115685614, 0.0017338707467118297, 0.00137867283611115, 0.001096256665761075, 0.000871702851441114, 0.0006931525317313003]

# %%
plt.figure(figsize =(18,8))



plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()

# %% [markdown]
# ### Overflow error

# %%
# overflow error explained ....... uncomment the below line to see the error

# %%
# local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.00001)

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.00001,
                                                 max_iter = 68)

# %%
plt.figure(figsize =(18,8))




plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()


print(local_min)

print('cost at local_min', h(local_min))

print('The max number of iterations', len(list_x))
# Out:
# -0.2813886166918419
# cost at local_min 1.9856970583078726
# The max number of iterations 69

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.00001,
                                                 max_iter = 69)

# %%
plt.figure(figsize =(18,8))




plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()


print(local_min)

print('cost at local_min', h(local_min))

print('The max number of iterations', len(list_x))
# Out:
# -0.2834845047819932
# cost at local_min 1.9852526030355775
# The max number of iterations 70

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.0001,
                                                 max_iter = 134)

# %%
plt.figure(figsize =(18,8))




plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()


print(local_min)

print('cost at local_min', h(local_min))

print('The max number of iterations', len(list_x))
# Out:
# -5782.279943653253
# cost at local_min -6.46614975669594e+18
# The max number of iterations 135

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.0001,
                                                 max_iter = 135)

# %%
plt.figure(figsize =(18,8))

plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()


print(local_min)

print('cost at local_min', h(local_min))

print('The max number of iterations', len(list_x))
# Out:
# -55909629653567.664
# cost at local_min -5.463023610279618e+68
# The max number of iterations 136

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.0001,
                                                 max_iter = 136)

# %%
plt.figure(figsize =(18,8))




plt.subplot(1,2,1)

plt.grid()
plt.plot(x_3, h(x_3))


values = np.array(list_x)
plt.xlim(-1.2, 2.5)
plt.ylim(-1,4)
plt.scatter(list_x, h(values), color = 'red')

plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.subplot(1,2,2)
plt.xlim(-1, 2)
plt.ylim(-4,5)
plt.grid()
plt.plot(x_3, dh(x_3))

plt.scatter(list_x, deriv_list, color = 'navy')

plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)


plt.show()


print(local_min)

print('cost at local_min', h(local_min))

print('The max number of iterations', len(list_x))
# Out:
# -4.885583793105108e+53
# cost at local_min -2.783442996149689e+268
# The max number of iterations 137

# %%
# -0.2813886166918419
# cost at local_min 1.9856970583078726
# The max number of iterations 69

# %%
# -0.2834845047819932
# cost at local_min 1.9852526030355775
# The max number of iterations 70

# %%
# -5782.279943653253
# cost at local_min -6.46614975669594e+18
# The max number of iterations 135

# %%
# -55909629653567.664
# cost at local_min -5.463023610279618e+68
# The max number of iterations 136

# %%
# -4.885583793105108e+53
# cost at local_min -2.783442996149689e+268
# The max number of iterations 137

# %%
# this is a overflow error
# local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.2, multiplier=0.01, precision=0.00001,
#                                                 max_iter = 137)

# %%
import sys

# %%
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %%
sys.float_info.min
# Out:
# 2.2250738585072014e-308

# %% [markdown]
# ### Learning rate or gamma or multiplier ....... how to fix that // ........can we fix that  at all?

# %% [markdown]
# # $$ g(x) = x^4 - 4x^2 + 5 $$

# %%
x_2 = np.linspace(-2, 2, 1000)

# %%
def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %%
def gradient_descent(initial_guess,  multiplier, precision, max_iter):
    
    
    new_x = initial_guess
    
    x_list = [new_x]
    
    slope_list = [dg(new_x)]
    

    for n in range(max_iter):
        
        previous_x = new_x 
        
        new_x = previous_x - multiplier * dg(previous_x)
        
        step_size = abs(new_x - previous_x)
        
        x_list.append(new_x)
        
        slope_list.append(dg(new_x))
        

        if step_size < precision:
            
            break
            
    return new_x, x_list, slope_list

# %%
n = 100
local_min, list_x, deriv_list = gradient_descent(initial_guess=1.9, multiplier = 0.25, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=(15, 5))


plt.subplot(1, 2, 1)

plt.grid()
plt.xlim(-2,2)
plt.ylim(-0.5, 6.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.5)
plt.scatter(list_x, g(np.array(list_x)), color='green', s=100, alpha=0.9)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()
   
print('Number of steps:', len(list_x))
print('Local min occurs at:', local_min)
# Out:
# Number of steps: 101
# Local min occurs at: -1.9684400420244323

# %%
# Setting gamma = 0.001

# %%
n = 100
local_min, list_x_2, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.001, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize = (20,10))

plt.xlim(0, n)
plt.ylim(0, 50)

plt.title('Effect of the learning rate 0.001', fontsize=17)
plt.xlabel('Nr of iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

iteration_list = list(range(0, n+1))


plt.plot(iteration_list,g(np.array(list_x_2)),color='green', linewidth=5)
plt.scatter(iteration_list,g(np.array(list_x_2)), color = 'green', s = 100)


plt.show()

# %%
# Setting gamma = 0.0002

# %%
n = 100
local_min, list_x_3, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0002, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize = (20,10))

plt.xlim(0, n)
plt.ylim(0, 50)

plt.title('Effect of the learning rate 0.0002', fontsize=17)
plt.xlabel('Nr of iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

iteration_list = list(range(0, n+1))


plt.plot(iteration_list,g(np.array(list_x_3)),color='blue', linewidth=5)
plt.scatter(iteration_list,g(np.array(list_x_3)), color = 'blue', s = 100)


plt.show()

# %%
# Setting gamma = 0.0001

# %%
n = 100
local_min, list_x_1, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0001, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize = (20,10))

plt.xlim(0, n)
plt.ylim(0, 50)

plt.title('Effect of the learning rate 0.0001', fontsize=17)
plt.xlabel('Nr of iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

iteration_list = list(range(0, n+1))


plt.plot(iteration_list,g(np.array(list_x_1)),color='pink', linewidth=5)
plt.scatter(iteration_list,g(np.array(list_x_1)), color = 'red', s = 100)


plt.show()

# %%
n= 100
local_min, list_x_1, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0001, precision =0.0001, max_iter = n)
local_min, list_x_2, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.001, precision =0.0001, max_iter = n)
local_min, list_x_3, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0002, precision =0.0001, max_iter = n)
local_min, list_x_4, deriv_list = gradient_descent(initial_guess=1.9, multiplier = 0.25, precision =0.0001, max_iter = n)


plt.figure(figsize=(20, 10))
# Lims and Titles....
plt.xlim(0, n)
plt.ylim(0, 50)
plt.title('Effect of the learning rate...All combined', fontsize=17)
plt.xlabel('Nr of iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

# plots 1 ......
plt.plot(iteration_list, g(np.array(list_x_1)), color='pink', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_1)), color='red', s=80)
# plots 2 .....
plt.plot(iteration_list, g(np.array(list_x_2)), color='green', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_2)), color='green', s=80, alpha =0.9)
# plot 3 .....
plt.plot(iteration_list, g(np.array(list_x_3)), color='blue', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_3)), color='blue', s=80, alpha =0.9)

# plot 4.......
plt.plot(iteration_list, g(np.array(list_x_4)), color='black', linewidth=5, alpha = .9)
plt.scatter(iteration_list, g(np.array(list_x_4)), color='red', s=80)

plt.show()
