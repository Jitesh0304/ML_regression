# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
data_1 = pd.read_csv('bitcoin.csv')

# %%
data_1.head()
# Out:
#         Date        Price
# 0  5/23/2019  7881.846680
# 1  5/24/2019  7987.371582
# 2  5/25/2019  8052.543945
# 3  5/26/2019  8673.215820
# 4  5/27/2019  8805.778320

# %%
data_1.drop(['Date'],1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1972\702620709.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data_1.drop(['Date'],1,inplace=True)                            # axis = 1  (for column)                 axis = 0 (for row)

# %%
data_1.head()
# Out:
#          Price
# 0  7881.846680
# 1  7987.371582
# 2  8052.543945
# 3  8673.215820
# 4  8805.778320

# %%
data_1
# Out:
#            Price
# 0    7881.846680
# 1    7987.371582
# 2    8052.543945
# 3    8673.215820
# 4    8805.778320
# ..           ...
# 362  9729.038086
# 363  9522.981445
# 364  9081.761719
# 365  9182.577148
# 366  9180.045898
#
# [367 rows x 1 columns]

# %%
data_1.index
# Out:
# RangeIndex(start=0, stop=367, step=1)

# %%
predictionday = 30                                                      

data_1['Prediction'] = data_1[['Price']].shift(predictionday)
data_1.head()
# Out:
#          Price  Prediction
# 0  7881.846680         NaN
# 1  7987.371582         NaN
# 2  8052.543945         NaN
# 3  8673.215820         NaN
# 4  8805.778320         NaN

# %%
data_1.tail()
# Out:
#            Price   Prediction
# 362  9729.038086  7189.424805
# 363  9522.981445  6881.958496
# 364  9081.761719  6880.323242
# 365  9182.577148  7117.207520
# 366  9180.045898  7429.724609

# %%
predictionday = 30                                                        

data_1['Prediction'] = data_1['Price'].shift(predictionday)

data_1.head()
# Out:
#          Price  Prediction
# 0  7881.846680         NaN
# 1  7987.371582         NaN
# 2  8052.543945         NaN
# 3  8673.215820         NaN
# 4  8805.778320         NaN

# %%
data_1.shape
# Out:
# (367, 2)

# %%
predictionday = 30                                                          
                                                                                    
data_1['Prediction'] = data_1['Price'].shift(-predictionday)
data_1.head()
# Out:
#          Price   Prediction
# 0  7881.846680  10701.69141
# 1  7987.371582  10855.37109
# 2  8052.543945  11011.10254
# 3  8673.215820  11790.91699
# 4  8805.778320  13016.23145

# %%
data_1.tail()
# Out:
#            Price  Prediction
# 362  9729.038086         NaN
# 363  9522.981445         NaN
# 364  9081.761719         NaN
# 365  9182.577148         NaN
# 366  9180.045898         NaN

# %%
data_1.shape
# Out:
# (367, 2)

# %%
x = np.array(data_1.drop(['Prediction'], axis = 1))
x = x[:len(data_1)-predictionday]

print(x)
# Out:
# [[ 7881.84668 ]
#  [ 7987.371582]
#  [ 8052.543945]
#  [ 8673.21582 ]
#  [ 8805.77832 ]
#  [ 8719.961914]
#  [ 8659.487305]
#  [ 8319.472656]
#  [ 8574.501953]
#  [ 8564.016602]
#  [ 8742.958008]
#  [ 8208.995117]
#  [ 7707.770996]
#  [ 7824.231445]
#  [ 7822.023438]
#  [ 8043.951172]
#  [ 7954.12793 ]
#  [ 7688.077148]
#  [ 8000.32959 ]
#  [ 7927.714355]
#  [ 8145.857422]
#  [ 8230.923828]
#  [ 8693.833008]
#  [ 8838.375   ]
#  [ 8994.488281]
#  [ 9320.352539]
#  [ 9081.762695]
#  [ 9273.521484]
#  [ 9527.160156]
#  [10144.55664 ]
#  [10701.69141 ]
#  [10855.37109 ]
#  [11011.10254 ]
#  [11790.91699 ]
#  [13016.23145 ]
#  [11182.80664 ]
#  [12407.33203 ]
#  [11959.37109 ]
#  [10817.15527 ]
#  [10583.13477 ]
#  [10801.67773 ]
#  [11961.26953 ]
#  [11215.4375  ]
#  [10978.45996 ]
#  [11208.55078 ]
#  [11450.84668 ]
#  [12285.95801 ]
#  [12573.8125  ]
#  [12156.5127  ]
#  [11358.66211 ]
#  [11815.98633 ]
#  [11392.37891 ]
#  [10256.05859 ]
#  [10895.08984 ]
#  [ 9477.641602]
# ...

# %%
len(x)
# Out:
# 337

# %%
# Create the dependent data set
# convert the data frame into a numpy array

y = np.array(data_1['Prediction'])

y = y[:-predictionday]

print(y)
# Out:
# [10701.69141  10855.37109  11011.10254  11790.91699  13016.23145
#  11182.80664  12407.33203  11959.37109  10817.15527  10583.13477
#  10801.67773  11961.26953  11215.4375   10978.45996  11208.55078
#  11450.84668  12285.95801  12573.8125   12156.5127   11358.66211
#  11815.98633  11392.37891  10256.05859  10895.08984   9477.641602
#   9693.802734 10666.48242  10530.73242  10767.13965  10599.10547
#  10343.10645   9900.767578  9811.925781  9911.841797  9870.303711
#   9477.677734  9552.860352  9519.145508  9607.423828 10085.62793
#  10399.66895  10518.17481  10821.72656  10970.18457  11805.65332
#  11478.16895  11941.96875  11966.40723  11862.93652  11354.02441
#  11523.5791   11382.61621  10895.83008  10051.7041   10311.5459
#  10374.33887  10231.74414  10345.81055  10916.05371  10763.23242
#  10138.04981  10131.05566  10407.96484  10159.96094  10138.51758
#  10370.82031  10185.5       9754.422852  9510.200195  9598.173828
# ...

# %%
len(y)
# Out:
# 337

# %%
## train test split

xtrain , xtest , ytrain , ytest = train_test_split(x , y , test_size = 0.2)

# %%
# set the predictiondays array equal to all rows from the original data set                                                                                         
predictionday_array = np.array(data_1.drop(['Prediction'] , axis = 1))
print(predictionday_array)
# Out:
# [[ 7881.84668 ]
#  [ 7987.371582]
#  [ 8052.543945]
#  [ 8673.21582 ]
#  [ 8805.77832 ]
#  [ 8719.961914]
#  [ 8659.487305]
#  [ 8319.472656]
#  [ 8574.501953]
#  [ 8564.016602]
#  [ 8742.958008]
#  [ 8208.995117]
#  [ 7707.770996]
#  [ 7824.231445]
#  [ 7822.023438]
#  [ 8043.951172]
#  [ 7954.12793 ]
#  [ 7688.077148]
#  [ 8000.32959 ]
#  [ 7927.714355]
#  [ 8145.857422]
#  [ 8230.923828]
#  [ 8693.833008]
#  [ 8838.375   ]
#  [ 8994.488281]
#  [ 9320.352539]
#  [ 9081.762695]
#  [ 9273.521484]
#  [ 9527.160156]
#  [10144.55664 ]
#  [10701.69141 ]
#  [10855.37109 ]
#  [11011.10254 ]
#  [11790.91699 ]
#  [13016.23145 ]
#  [11182.80664 ]
#  [12407.33203 ]
#  [11959.37109 ]
#  [10817.15527 ]
#  [10583.13477 ]
#  [10801.67773 ]
#  [11961.26953 ]
#  [11215.4375  ]
#  [10978.45996 ]
#  [11208.55078 ]
#  [11450.84668 ]
#  [12285.95801 ]
#  [12573.8125  ]
#  [12156.5127  ]
#  [11358.66211 ]
#  [11815.98633 ]
#  [11392.37891 ]
#  [10256.05859 ]
#  [10895.08984 ]
#  [ 9477.641602]
# ...

# %%
# set the predictiondays array equal to last 30 rows from the original data set

predictionday_array = np.array(data_1.drop(['Prediction'] , axis = 1))[-predictionday:]
print(predictionday_array)
# Out:
# [[7550.900879]
#  [7569.936035]
#  [7679.867188]
#  [7795.601074]
#  [7807.058594]
#  [8801.038086]
#  [8658.553711]
#  [8864.766602]
#  [8988.59668 ]
#  [8897.46875 ]
#  [8912.654297]
#  [9003.070313]
#  [9268.761719]
#  [9951.518555]
#  [9842.666016]
#  [9593.896484]
#  [8756.430664]
#  [8601.795898]
#  [8804.477539]
#  [9269.987305]
#  [9733.72168 ]
#  [9328.197266]
#  [9377.013672]
#  [9670.739258]
#  [9726.575195]
#  [9729.038086]
#  [9522.981445]
#  [9081.761719]
#  [9182.577148]
#  [9180.045898]]

# %%
svr_rbf = SVR(kernel = 'rbf' , C = 1e3 , gamma = 0.00001)
svr_rbf.fit(xtrain , ytrain)
# Out:
# SVR(C=1000.0, gamma=1e-05)

# %%
# testing

svr_rbf_confidence = svr_rbf.score(xtest , ytest)

print('SVR_RBF_ accuracy :', svr_rbf_confidence)
# Out:
# SVR_RBF_ accuracy : -0.0888913314084292

# %%
# print the prediction values

svr_prediction = svr_rbf.predict(xtest)
print(svr_prediction)

print()

print(ytest)
# Out:
# [ 8521.47506807  8505.02790888  8264.67102661  8172.37213165
#   8869.25528368  8921.58376654  8448.43966918  8220.94676661
#   9507.67031225  8890.6955531   7926.6563401   8804.70106485
#  10386.82815808  8446.51148797  8213.34888787  8655.04702516
#   7945.80322498  8236.30439418 10042.63406353  8747.3243122
#  10005.34617003  8224.16879873  8241.62177353  8953.76716167
#   9314.21581507 11154.71101627  8750.35609073  8756.00543302
#   9398.37007172  8281.78376842  9553.45461962  9889.66251977
#   8781.4306022   8395.51570066  7746.27681562  8847.126116
#   8076.51978951  9265.2288214   9063.54814272  8671.53904686
#   9252.38536343  8986.27724243  9134.80822034  9399.95415586
#   9265.81362326 10387.00404407 10741.2683214   7425.15520857
#  10488.7442681  10130.34537475  8269.23963973  8816.89079931
#   8929.17717955  8699.94050425  9124.4176855   9317.21631015
#   9284.9473534   9039.63751402  9899.77230357  8138.3402649
# ...

# %%
# Print the model predictions for the next 30 days

svr_prediction = svr_rbf.predict(predictionday_array)
print(svr_prediction)
print()

#Print the actual price for bitcoin for last 30 days

print(data_1.tail(predictionday))
# Out:
# [7962.29078988 8041.75163209 8850.36133211 9791.43218314 9858.12478494
#  9296.19322544 9073.91543863 9080.28603662 8280.82224913 8898.36070327
#  8802.23552535 8185.80070567 7975.98826895 8223.70988732 8123.75946581
#  8368.9013988  9319.55362361 8863.94189708 9289.95396487 7980.87700005
#  8134.27377434 8215.57508837 8381.9875099  8218.10915233 8141.02877051
#  8138.61486586 8490.22904118 7789.26610584 7712.02643501 7707.93398963]
#
#            Price  Prediction
# 337  7550.900879         NaN
# 338  7569.936035         NaN
# 339  7679.867188         NaN
# 340  7795.601074         NaN
# 341  7807.058594         NaN
# 342  8801.038086         NaN
# 343  8658.553711         NaN
# 344  8864.766602         NaN
# 345  8988.596680         NaN
# 346  8897.468750         NaN
# 347  8912.654297         NaN
# 348  9003.070313         NaN
# 349  9268.761719         NaN
# 350  9951.518555         NaN
# 351  9842.666016         NaN
# 352  9593.896484         NaN
# 353  8756.430664         NaN
# ...
